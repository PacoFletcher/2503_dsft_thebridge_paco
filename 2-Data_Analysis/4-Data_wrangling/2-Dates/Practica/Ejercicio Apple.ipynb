# %% [markdown]
# # Apple Stock

# %% [markdown]
# ### Introduction:
#
# We are going to use Apple's stock price.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv)

# %%
data = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv")
data
# Out:
#             Date   Open   High    Low  Close     Volume  Adj Close
# 0     2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1     2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2     2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3     2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4     2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...    ...    ...    ...    ...        ...        ...
# 8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable apple and apply a head()

# %%
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv"
apple = pd.read_csv(url)
apple.head()
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# ### Step 4.  Check out the type of the columns

# %%
apple.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %%
from datetime import datetime
from dateutil import parser

# %% [markdown]
# ### Step 5. Transform the Date column as a datetime type and check the info()

# %%
apple["Date"]
# Out:
# 0       2014-07-08
# 1       2014-07-07
# 2       2014-07-03
# 3       2014-07-02
# 4       2014-07-01
#            ...
# 8460    1980-12-18
# 8461    1980-12-17
# 8462    1980-12-16
# 8463    1980-12-15
# 8464    1980-12-12
# Name: Date, Length: 8465, dtype: object

# %%
apple["Date"] = pd.to_datetime(apple["Date"])

# %%
apple.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume                int64
# Adj Close           float64
# dtype: object

# %% [markdown]
# ### Step 6.  Set the date as the index

# %%
apple.set_index("Date", inplace=True)
apple
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...           ...    ...    ...    ...        ...        ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 6 columns]

# %% [markdown]
# ### Step 7.  Is there any duplicate dates?

# %%
apple.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  8465.000000  8465.000000  8465.000000  8465.000000  8.465000e+03
# mean     98.593926    99.848683    97.226790    98.549199  9.391214e+07
# std     141.965350   143.155674   140.548326   141.877244  8.993202e+07
# min      11.120000    11.120000    11.000000    11.000000  2.504000e+05
# 25%      25.750000    26.000000    25.120000    25.630000  3.704960e+07
# 50%      40.750000    41.500000    40.000000    40.750000  6.636000e+07
# 75%      79.500000    81.000000    78.740000    80.000000  1.177701e+08
# max     702.410000   705.070000   699.570000   702.100000  1.855410e+09
#
#          Adj Close         Year        Month          Day
# count  8465.000000  8465.000000  8465.000000  8465.000000
# mean     11.095014  1997.214885     6.500177    15.739634
# std      21.133016     9.691911     3.436025     8.746713
# min       0.170000  1980.000000     1.000000     1.000000
# ...

# %%
apple.index
# Out:
# DatetimeIndex(['2014-07-08', '2014-07-07', '2014-07-03', '2014-07-02',
#                '2014-07-01', '2014-06-30', '2014-06-27', '2014-06-26',
#                '2014-06-25', '2014-06-24',
#                ...
#                '1980-12-26', '1980-12-24', '1980-12-23', '1980-12-22',
#                '1980-12-19', '1980-12-18', '1980-12-17', '1980-12-16',
#                '1980-12-15', '1980-12-12'],
#               dtype='datetime64[ns]', name='Date', length=8465, freq=None)

# %%
apple.index.nunique()
# Out:
# 8465

# %% [markdown]
# Aparentemente todas las fechas son únicas, no hay ningún valor repetido.

# %% [markdown]
# ### Step 8.  Ops...it seems the index is from the most recent date. Make the first entry the oldest date.

# %%
apple.sort_index()
# Out:
#              Open   High    Low  Close     Volume  Adj Close  Year  Month  Day
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45  1980     12   12
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42  1980     12   15
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39  1980     12   16
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40  1980     12   17
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41  1980     12   18
# ...           ...    ...    ...    ...        ...        ...   ...    ...  ...
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52  2014      7    1
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48  2014      7    2
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03  2014      7    3
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97  2014      7    7
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35  2014      7    8
#
# ...

# %% [markdown]
# No sé qué se pretende que tengo que hacer aquí...

# %% [markdown]
# ### Step 9. Get the last business day of each month

# %%
apple["last_buss_day"] = apple.index.map(lambda ser: pd.to_datetime((ser - pd.offsets.BDay(1))))
apple
# Out:
#              Open   High    Low  Close     Volume  Adj Close  Year  Month  \
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35  2014      7
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97  2014      7
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03  2014      7
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48  2014      7
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52  2014      7
# ...           ...    ...    ...    ...        ...        ...   ...    ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41  1980     12
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40  1980     12
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39  1980     12
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42  1980     12
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45  1980     12
#
#             Day last_buss_day
# Date
# 2014-07-08    8    2014-07-07
# ...

# %%
apple["Year"] = apple.index.year
apple
# Out:
#              Open   High    Low  Close     Volume  Adj Close  Year  Month  Day
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35  2014      7    8
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97  2014      7    7
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03  2014      7    3
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48  2014      7    2
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52  2014      7    1
# ...           ...    ...    ...    ...        ...        ...   ...    ...  ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41  1980     12   18
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40  1980     12   17
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39  1980     12   16
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42  1980     12   15
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45  1980     12   12
#
# ...

# %%
apple["Month"]  = apple.index.month
apple
# Out:
#              Open   High    Low  Close     Volume  Adj Close  Year  Month  Day
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35  2014      7    8
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97  2014      7    7
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03  2014      7    3
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48  2014      7    2
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52  2014      7    1
# ...           ...    ...    ...    ...        ...        ...   ...    ...  ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41  1980     12   18
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40  1980     12   17
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39  1980     12   16
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42  1980     12   15
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45  1980     12   12
#
# ...

# %%
apple["Day"] = apple.index.day
apple
# Out:
#              Open   High    Low  Close     Volume  Adj Close  Year  Month  Day
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35  2014      7    8
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97  2014      7    7
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03  2014      7    3
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48  2014      7    2
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52  2014      7    1
# ...           ...    ...    ...    ...        ...        ...   ...    ...  ...
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41  1980     12   18
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40  1980     12   17
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39  1980     12   16
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42  1980     12   15
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45  1980     12   12
#
# ...

# %%
apple.groupby(["Year","Month"])[["Year","Month","Day"]].max("Day")
# Out:
#             Year  Month  Day
# Year Month
# 1980 12     1980     12   31
# 1981 1      1981      1   30
#      2      1981      2   27
#      3      1981      3   31
#      4      1981      4   30
# ...          ...    ...  ...
# 2014 3      2014      3   31
#      4      2014      4   30
#      5      2014      5   30
#      6      2014      6   30
#      7      2014      7    8
#
# [404 rows x 3 columns]

# %%
apple.asfreq(freq = "BME")
# Out:
#               Open    High     Low   Close       Volume  Adj Close    Year  \
# Date
# 2014-02-28  529.08  532.75  522.12  526.24   92992200.0      74.76  2014.0
# 2014-03-31  539.23  540.81  535.93  536.74   42167300.0      76.25  2014.0
# 2014-04-30  592.64  599.43  589.80  590.09  114160200.0      83.83  2014.0
# 2014-05-30  637.98  644.17  628.90  633.00  141005200.0      90.43  2014.0
# 2014-06-30   92.10   93.73   92.09   92.93   49482300.0      92.93  2014.0
#
#             Month   Day last_buss_day
# Date
# 2014-02-28    2.0  28.0    2014-02-27
# 2014-03-31    3.0  31.0    2014-03-28
# 2014-04-30    4.0  30.0    2014-04-29
# 2014-05-30    5.0  30.0    2014-05-29
# 2014-06-30    6.0  30.0    2014-06-27

# %% [markdown]
# ### Step 10.  What is the difference in days between the first day and the oldest

# %%
print(apple.index[0])
print(apple.index[-1])
# Out:
# 2014-07-08 00:00:00
# 1980-12-12 00:00:00

# %%
(apple.index[0]-apple.index[-1]).days
# Out:
# 12261

# %% [markdown]
# ### Step 11.  How many months in the data we have?

# %%
anys = apple.index[0].year -apple.index[-1].year
anys
# Out:
# 34

# %%
meses = apple.index[0].month - apple.index[-1].month
meses
# Out:
# -5

# %%
meses_dif = anys*12 + meses
meses_dif
# Out:
# 404

# %%
(apple.index[0].year -apple.index[-1].year)*12 + (apple.index[0].month - apple.index[-1].month)
# Out:
# 403

# %% [markdown]
# ### Step 12. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
apple.head()
# Out:
#              Open   High    Low  Close    Volume  Adj Close  Year  Month  Day
# Date
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35  2014      7    8
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97  2014      7    7
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03  2014      7    3
# 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48  2014      7    2
# 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52  2014      7    1

# %%
plt.figure(figsize = (13.5,9))
apple["Adj Close"].plot(xlabel="Year",ylabel="Value")
plt.title("Adj Close");
